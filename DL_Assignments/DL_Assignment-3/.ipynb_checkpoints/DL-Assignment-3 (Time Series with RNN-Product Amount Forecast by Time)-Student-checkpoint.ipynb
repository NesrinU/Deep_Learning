# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Assignment-3 (RNN)<br><br>Product Amount Forecast by Time<br><h1>

# %% [markdown]
# # Dataset Info
#
# Info about this data set: https://fred.stlouisfed.org/series/IPN31152N
#
#
# Units:  Index 2012=100, Not Seasonally Adjusted
#
# Frequency:  Monthly
#
# The industrial production (IP) index measures the real output of all relevant establishments located in the United States, regardless of their ownership, but not those located in U.S. territories.
#
# NAICS = 31152
#
# Source Code: IP.N31152.N
#
# Suggested Citation:
# Board of Governors of the Federal Reserve System (US), Industrial Production: Nondurable Goods: Ice cream and frozen dessert [IPN31152N], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/IPN31152N, November 16, 2019.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Indest Data

# %%
df = pd.read_csv('Frozen_Dessert_Production.csv',
                index_col='DATE',
                parse_dates=True
                )

# %%
df.head()
# Out:
#             IPN31152N
# DATE
# 1972-01-01     59.962
# 1972-02-01     67.061
# 1972-03-01     74.235
# 1972-04-01     78.112
# 1972-05-01     84.764

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Change the column name as "Production"
# 2. Plot your data and see its seasonalty

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 573 entries, 1972-01-01 to 2019-09-01
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IPN31152N  573 non-null    float64
# dtypes: float64(1)
# memory usage: 9.0 KB

# %%
df.columns = ['Production']

# %%
df.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Preprocessing of Data

# %% [markdown]
# ## Train Test Split

# %%
len(df)
# Out:
# 573

# %%
test_size = 36

# %%
test_ind = len(df)- test_size
test_ind
# Out:
# 537

# %%
train = df.iloc[:test_ind]
test = df.iloc[test_ind:]

# %%
train
# Out:
#             Production
# DATE
# 1972-01-01      59.962
# 1972-02-01      67.061
# 1972-03-01      74.235
# 1972-04-01      78.112
# 1972-05-01      84.764
# ...                ...
# 2016-05-01     121.543
# 2016-06-01     132.987
# 2016-07-01     124.851
# 2016-08-01     121.332
# 2016-09-01     108.036
#
# [537 rows x 1 columns]

# %%
test
# Out:
#             Production
# DATE
# 2016-10-01     101.384
# 2016-11-01      86.665
# 2016-12-01      81.257
# 2017-01-01      94.245
# 2017-02-01     112.388
# 2017-03-01     119.698
# 2017-04-01     123.228
# 2017-05-01     116.064
# 2017-06-01     123.087
# 2017-07-01     116.264
# 2017-08-01     113.172
# 2017-09-01      97.912
# 2017-10-01      90.473
# 2017-11-01      77.438
# 2017-12-01      75.812
# 2018-01-01      83.434
# 2018-02-01      99.490
# 2018-03-01     107.315
# 2018-04-01     112.431
# 2018-05-01     110.354
# 2018-06-01     124.584
# 2018-07-01     117.222
# 2018-08-01     112.678
# 2018-09-01     103.312
# 2018-10-01      92.132
# 2018-11-01      82.435
# 2018-12-01      76.761
# 2019-01-01      86.999
# 2019-02-01      98.112
# 2019-03-01     116.172
# 2019-04-01     114.970
# 2019-05-01     114.561
# 2019-06-01     124.960
# 2019-07-01     110.263
# 2019-08-01     102.609
# 2019-09-01     101.587

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %% [markdown]
# ## Time Series Generator

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 12
batch_size = 1
generator = TimeseriesGenerator(train_scaled, train_scaled, length = length, batch_size = batch_size)

# %%
len(generator)
# Out:
# 525

# %%
generator[0]
# Out:
# (array([[[0.00947104],
#          [0.06108982],
#          [0.11326273],
#          [0.14145625],
#          [0.18982663],
#          [0.30495972],
#          [0.30154406],
#          [0.27416065],
#          [0.19736841],
#          [0.08532665],
#          [0.01561588],
#          [0.        ]]]),
#  array([[0.01774221]]))

# %%
X, y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.00947104 0.06108982 0.11326273 0.14145625 0.18982663 0.30495972
#  0.30154406 0.27416065 0.19736841 0.08532665 0.01561588 0.        ]
# Predict this y:
#  [[0.01774221]]

# %% [markdown]
# # Modelling & Model Performance

# %% [markdown]
# ## with "tanh" activation function

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from keras.layers import Dropout

# %%
train_scaled.shape
# Out:
# (537, 1)

# %%
n_features = train_scaled.shape[1]

# %%
model = Sequential()
model.add(LSTM(100, activation = 'tanh', return_sequences=True, input_shape = (length, n_features)))
model.add(LSTM(50, activation = 'tanh'))

model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 100)           40800
#
#  lstm_1 (LSTM)               (None, 50)                30200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor = 'val_loss', patience = 6, restore_best_weights = True)

# %%
validation_generator = TimeseriesGenerator(test_scaled, test_scaled, length = length, batch_size = 1)

# %%
len(validation_generator)
# Out:
# 24

# %%
model.fit_generator(generator, epochs = 120,
                    validation_data = validation_generator,
                    callbacks = [early_stop])
# Out:
# Epoch 1/120
# 525/525 [==============================] - 7s 8ms/step - loss: 0.0181 - val_loss: 0.0054
# Epoch 2/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 3/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0049 - val_loss: 0.0022
# Epoch 4/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 5/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 6/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 7/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 8/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 9/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 10/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 11/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 12/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 13/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 14/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 15/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 16/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 17/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 18/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 19/120
# 525/525 [==============================] - 4s 7ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 20/120
# 525/525 [==============================] - 4s 8ms/step - loss: 0.0025 - val_loss: 0.0026

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Evaluation on Test Data

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %%
validation_generator[0]
# Out:
# (array([[[0.31068714],
#          [0.20365141],
#          [0.16432593],
#          [0.2587782 ],
#          [0.39071032],
#          [0.44387077],
#          [0.4695409 ],
#          [0.41743926],
#          [0.46851409],
#          [0.41889656],
#          [0.39641011],
#          [0.28544533]]]),
#  array([[0.23134679]]))

# %%
test_scaled
# Out:
# array([[0.31068714],
#        [0.20365141],
#        [0.16432593],
#        [0.2587782 ],
#        [0.39071032],
#        [0.44387077],
#        [0.4695409 ],
#        [0.41743926],
#        [0.46851409],
#        [0.41889656],
#        [0.39641011],
#        [0.28544533],
#        [0.23134679],
#        [0.13655347],
#        [0.12472921],
#        [0.18015997],
#        [0.29691617],
#        [0.35382169],
#        [0.39102302],
#        [0.37592272],
#        [0.47940099],
#        [0.42586022],
#        [0.3928192 ],
#        [0.32470899],
#        [0.2434103 ],
#        [0.17289089],
#        [0.13163033],
#        [0.20608099],
#        [0.28689318],
#        [0.41822681],
#        [0.40948951],
#        [0.40651527],
#        [0.48213817],
#        [0.37525952],
#        [0.3195946 ],
#        [0.31216335]])

# %%
y_pred = model.predict(validation_generator)
# Out:
# 24/24 [==============================] - 1s 3ms/step

# %%
y_pred
# Out:
# array([[0.2150326 ],
#        [0.20052814],
#        [0.16846246],
#        [0.20563065],
#        [0.25945252],
#        [0.33969593],
#        [0.38879928],
#        [0.43167856],
#        [0.42138493],
#        [0.43896845],
#        [0.36330175],
#        [0.29163033],
#        [0.22217388],
#        [0.16958746],
#        [0.15539142],
#        [0.17263907],
#        [0.26052064],
#        [0.3231464 ],
#        [0.4237218 ],
#        [0.44673923],
#        [0.44610095],
#        [0.44639376],
#        [0.32784143],
#        [0.23200706]], dtype=float32)

# %%
len(y_pred)
# Out:
# 24

# %%
test_scaled[12:]
# Out:
# array([[0.23134679],
#        [0.13655347],
#        [0.12472921],
#        [0.18015997],
#        [0.29691617],
#        [0.35382169],
#        [0.39102302],
#        [0.37592272],
#        [0.47940099],
#        [0.42586022],
#        [0.3928192 ],
#        [0.32470899],
#        [0.2434103 ],
#        [0.17289089],
#        [0.13163033],
#        [0.20608099],
#        [0.28689318],
#        [0.41822681],
#        [0.40948951],
#        [0.40651527],
#        [0.48213817],
#        [0.37525952],
#        [0.3195946 ],
#        [0.31216335]])

# %%
eval_metrics(test_scaled[12:], y_pred)
# Out:
# r2_score: 0.8444465141538413
#  mae: 0.035250365800145546
#  mse: 0.0018205467848674314
#  rmse: 0.04266786595164365

# %%
test_predictions = []

first_eval_batch = train_scaled[-length:]

current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
# Out:
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
train.shape
# Out:
# (537, 1)

# %%
test_predictions
# Out:
# [array([0.24625024], dtype=float32),
#  array([0.1709799], dtype=float32),
#  array([0.16664067], dtype=float32),
#  array([0.22284698], dtype=float32),
#  array([0.28891933], dtype=float32),
#  array([0.34219787], dtype=float32),
#  array([0.38943064], dtype=float32),
#  array([0.43514985], dtype=float32),
#  array([0.46888262], dtype=float32),
#  array([0.46125126], dtype=float32),
#  array([0.40801817], dtype=float32),
#  array([0.32100394], dtype=float32),
#  array([0.22713149], dtype=float32),
#  array([0.1592234], dtype=float32),
#  array([0.14840665], dtype=float32),
#  array([0.19190335], dtype=float32),
#  array([0.2527414], dtype=float32),
#  array([0.3065611], dtype=float32),
#  array([0.35497123], dtype=float32),
#  array([0.40111026], dtype=float32),
#  array([0.43314976], dtype=float32),
#  array([0.42883608], dtype=float32),
#  array([0.37945274], dtype=float32),
#  array([0.2982791], dtype=float32),
#  array([0.2091167], dtype=float32),
#  array([0.1421345], dtype=float32),
#  array([0.12721555], dtype=float32),
#  array([0.16566584], dtype=float32),
#  array([0.22508323], dtype=float32),
#  array([0.28003293], dtype=float32),
#  array([0.32945424], dtype=float32),
#  array([0.37583363], dtype=float32),
#  array([0.40819323], dtype=float32),
#  array([0.4056684], dtype=float32),
#  array([0.35901842], dtype=float32),
#  array([0.28010476], dtype=float32)]

# %%
eval_metrics(test_scaled, test_predictions)
# Out:
# r2_score: 0.7814978707129376
#  mae: 0.03963805744926827
#  mse: 0.0025146748986349336
#  rmse: 0.0501465342634457

# %% [markdown]
# ### Inverse Transformation and Comparing

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test
# Out:
#             Production
# DATE
# 2016-10-01     101.384
# 2016-11-01      86.665
# 2016-12-01      81.257
# 2017-01-01      94.245
# 2017-02-01     112.388
# 2017-03-01     119.698
# 2017-04-01     123.228
# 2017-05-01     116.064
# 2017-06-01     123.087
# 2017-07-01     116.264
# 2017-08-01     113.172
# 2017-09-01      97.912
# 2017-10-01      90.473
# 2017-11-01      77.438
# 2017-12-01      75.812
# 2018-01-01      83.434
# 2018-02-01      99.490
# 2018-03-01     107.315
# 2018-04-01     112.431
# 2018-05-01     110.354
# 2018-06-01     124.584
# 2018-07-01     117.222
# 2018-08-01     112.678
# 2018-09-01     103.312
# 2018-10-01      92.132
# 2018-11-01      82.435
# 2018-12-01      76.761
# 2019-01-01      86.999
# 2019-02-01      98.112
# 2019-03-01     116.172
# 2019-04-01     114.970
# 2019-05-01     114.561
# 2019-06-01     124.960
# 2019-07-01     110.263
# 2019-08-01     102.609
# 2019-09-01     101.587

# %%
test['Predictions'] = true_predictions

# %%
test
# Out:
#             Production  Predictions
# DATE
# 2016-10-01     101.384       92.523
# 2016-11-01      86.665       82.172
# 2016-12-01      81.257       81.575
# 2017-01-01      94.245       89.304
# 2017-02-01     112.388       98.390
# 2017-03-01     119.698      105.717
# 2017-04-01     123.228      112.212
# 2017-05-01     116.064      118.499
# 2017-06-01     123.087      123.138
# 2017-07-01     116.264      122.088
# 2017-08-01     113.172      114.768
# 2017-09-01      97.912      102.802
# 2017-10-01      90.473       89.894
# 2017-11-01      77.438       80.555
# 2017-12-01      75.812       79.068
# 2018-01-01      83.434       85.049
# 2018-02-01      99.490       93.415
# 2018-03-01     107.315      100.816
# 2018-04-01     112.431      107.473
# 2018-05-01     110.354      113.818
# 2018-06-01     124.584      118.224
# 2018-07-01     117.222      117.631
# 2018-08-01     112.678      110.840
# 2018-09-01     103.312       99.677
# 2018-10-01      92.132       87.416
# 2018-11-01      82.435       78.205
# 2018-12-01      76.761       76.154
# 2019-01-01      86.999       81.441
# 2019-02-01      98.112       89.612
# 2019-03-01     116.172       97.168
# 2019-04-01     114.970      103.964
# 2019-05-01     114.561      110.342
# 2019-06-01     124.960      114.792
# 2019-07-01     110.263      114.445
# 2019-08-01     102.609      108.030
# 2019-09-01     101.587       97.178

# %%
test.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
eval_metrics(test.Production, test.Predictions)
# Out:
# r2_score: 0.7814978707129373
#  mae: 5.450783868272936
#  mse: 47.55268513297716
#  rmse: 6.895845498050051

# %% [markdown]
# ## with "relu" activation function

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
n_features = 1

# %%
model = Sequential()
model.add(LSTM(100, activation = 'relu', return_sequences=True, input_shape = (length, n_features)))
model.add(LSTM(50, activation = 'relu'))

model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 100)           40800
#
#  lstm_3 (LSTM)               (None, 50)                30200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### EarlyStopping and Validation Generator

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor = 'val_loss', patience = 6)

# %%
validation_generator = TimeseriesGenerator(test_scaled, test_scaled, length = length, batch_size = 1)

# %%
len(validation_generator)
# Out:
# 24

# %%
model.fit_generator(generator, epochs = 120,
                    validation_data = validation_generator,
                    callbacks = [early_stop])
# Out:
# Epoch 1/120
# 525/525 [==============================] - 5s 6ms/step - loss: 0.0253 - val_loss: 0.0120
# Epoch 2/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0102 - val_loss: 0.0039
# Epoch 3/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0076 - val_loss: 0.0025
# Epoch 4/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 5/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 6/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 7/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 8/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 9/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0039 - val_loss: 0.0065
# Epoch 10/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 11/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 12/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0035 - val_loss: 0.0017
# Epoch 13/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 14/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 15/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 16/120
# 525/525 [==============================] - 3s 6ms/step - loss: 0.0031 - val_loss: 0.0019

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Evaluation on Test Data

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    score = r2_score(actual, pred)
    return print("r2_score:", score, "\n","mae:", mae, "\n","mse:",mse, "\n","rmse:",rmse)

# %%
y_pred = model.predict(validation_generator)
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.23683508],
#        [0.18493369],
#        [0.2044921 ],
#        [0.26930603],
#        [0.32100582],
#        [0.37660107],
#        [0.42145234],
#        [0.45309442],
#        [0.4423253 ],
#        [0.43875134],
#        [0.37875405],
#        [0.2968385 ],
#        [0.21401295],
#        [0.1509868 ],
#        [0.14797972],
#        [0.21795398],
#        [0.2911743 ],
#        [0.35562214],
#        [0.42240593],
#        [0.468839  ],
#        [0.4633745 ],
#        [0.4451365 ],
#        [0.36370274],
#        [0.26456738]], dtype=float32)

# %%
test_scaled[12:]
# Out:
# array([[0.23134679],
#        [0.13655347],
#        [0.12472921],
#        [0.18015997],
#        [0.29691617],
#        [0.35382169],
#        [0.39102302],
#        [0.37592272],
#        [0.47940099],
#        [0.42586022],
#        [0.3928192 ],
#        [0.32470899],
#        [0.2434103 ],
#        [0.17289089],
#        [0.13163033],
#        [0.20608099],
#        [0.28689318],
#        [0.41822681],
#        [0.40948951],
#        [0.40651527],
#        [0.48213817],
#        [0.37525952],
#        [0.3195946 ],
#        [0.31216335]])

# %%
eval_metrics(test_scaled[12:], y_pred)
# Out:
# r2_score: 0.8349424410121847
#  mae: 0.036297687379168005
#  mse: 0.001931779327854606
#  rmse: 0.04395201164741616

# %%
test_predictions = []

first_eval_batch = train_scaled[-length:]

current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
# Out:
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
eval_metrics(test_scaled, test_predictions)
# Out:
# r2_score: 0.4965097017953368
#  mae: 0.0636025674456066
#  mse: 0.005794517512175342
#  rmse: 0.07612172825268317

# %% [markdown]
# ### Inverse Transformation and Comparing

# %%
true_predictions_relu = scaler.inverse_transform(test_predictions)

# %%
test['Predictions_Relu'] = true_predictions_relu

# %%
test
# Out:
#             Production  Predictions  Predictions_Relu
# DATE
# 2016-10-01     101.384       92.523            93.531
# 2016-11-01      86.665       82.172            83.058
# 2016-12-01      81.257       81.575            82.798
# 2017-01-01      94.245       89.304            93.600
# 2017-02-01     112.388       98.390           104.975
# 2017-03-01     119.698      105.717           115.319
# 2017-04-01     123.228      112.212           123.063
# 2017-05-01     116.064      118.499           129.854
# 2017-06-01     123.087      123.138           132.624
# 2017-07-01     116.264      122.088           129.585
# 2017-08-01     113.172      114.768           120.718
# 2017-09-01      97.912      102.802           106.691
# 2017-10-01      90.473       89.894            92.467
# 2017-11-01      77.438       80.555            82.901
# 2017-12-01      75.812       79.068            85.126
# 2018-01-01      83.434       85.049            95.724
# 2018-02-01      99.490       93.415           106.783
# 2018-03-01     107.315      100.816           116.743
# 2018-04-01     112.431      107.473           125.291
# 2018-05-01     110.354      113.818           132.042
# 2018-06-01     124.584      118.224           134.472
# 2018-07-01     117.222      117.631           131.024
# 2018-08-01     112.678      110.840           120.893
# 2018-09-01     103.312       99.677           106.375
# 2018-10-01      92.132       87.416            92.154
# 2018-11-01      82.435       78.205            83.222
# 2018-12-01      76.761       76.154            86.830
# 2019-01-01      86.999       81.441            97.533
# 2019-02-01      98.112       89.612           108.545
# 2019-03-01     116.172       97.168           118.548
# 2019-04-01     114.970      103.964           127.103
# 2019-05-01     114.561      110.342           133.749
# 2019-06-01     124.960      114.792           135.852
# 2019-07-01     110.263      114.445           131.808
# 2019-08-01     102.609      108.030           121.026
# 2019-09-01     101.587       97.178           106.183

# %%
test.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
eval_metrics(test.Production, test.Predictions_Relu)
# Out:
# r2_score: 0.4965097017953374
#  mae: 8.746237099458398
#  mse: 109.57474737731397
#  rmse: 10.467795726766642

# %% [markdown]
# # Retrain and Forecasting
#
# Select activation function providing a better score, create your final model with full data, forecast for the next 12 months, and plot this forecast.

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 12 
generator = TimeseriesGenerator(scaled_full_data, scaled_full_data, length = length, batch_size = 1)

# %%
len(df)
# Out:
# 573

# %%
len(generator)
# Out:
# 561

# %%
model = Sequential()
model.add(LSTM(100, activation = 'tanh', return_sequences=True, input_shape = (length, n_features)))
model.add(LSTM(50, activation = 'tanh'))

model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

model.fit_generator(generator, epochs=120)
# Out:
# Epoch 1/120
# 561/561 [==============================] - 6s 7ms/step - loss: 0.0181
# Epoch 2/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0051
# Epoch 3/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0039
# Epoch 4/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0042
# Epoch 5/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0039
# Epoch 6/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0033
# Epoch 7/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0033
# Epoch 8/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0034
# Epoch 9/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0034
# Epoch 10/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0032
# Epoch 11/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0029
# Epoch 12/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0034
# Epoch 13/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0032
# Epoch 14/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0029
# Epoch 15/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0028
# Epoch 16/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0029
# Epoch 17/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0029
# Epoch 18/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0025
# Epoch 19/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0025
# Epoch 20/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0026
# Epoch 21/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0026
# Epoch 22/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0028
# Epoch 23/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0023
# Epoch 24/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0024
# Epoch 25/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0022
# Epoch 26/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0023
# Epoch 27/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0022
# Epoch 28/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0022
# Epoch 29/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0021
# Epoch 30/120
# 561/561 [==============================] - 4s 8ms/step - loss: 0.0021
# Epoch 31/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0021
# Epoch 32/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0019
# Epoch 33/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0018
# Epoch 34/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0021
# Epoch 35/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0020
# Epoch 36/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0019
# Epoch 37/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0018
# Epoch 38/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0019
# Epoch 39/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0018
# Epoch 40/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0017
# Epoch 41/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0018
# Epoch 42/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0017
# Epoch 43/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0017
# Epoch 44/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0016
# Epoch 45/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0018
# Epoch 46/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0017
# Epoch 47/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0016
# Epoch 48/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 49/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 50/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 51/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0016
# Epoch 52/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0016
# Epoch 53/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 54/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 55/120
# 561/561 [==============================] - 4s 6ms/step - loss: 0.0014
# Epoch 56/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 57/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 58/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 59/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 60/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 61/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 62/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 63/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0015
# Epoch 64/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 65/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 66/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 67/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 68/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0014
# Epoch 69/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 70/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 71/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 72/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 73/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 74/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 75/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 76/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 77/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 78/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0013
# Epoch 79/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 80/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 81/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 82/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 83/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 84/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 85/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 86/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 87/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 88/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 89/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 90/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0012
# Epoch 91/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 92/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.9715e-04
# Epoch 93/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 94/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0010
# Epoch 95/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 96/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.8494e-04
# Epoch 97/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0011
# Epoch 98/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.7923e-04
# Epoch 99/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.5288e-04
# Epoch 100/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0010
# Epoch 101/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.9790e-04
# Epoch 102/120
# 561/561 [==============================] - 4s 7ms/step - loss: 0.0010
# Epoch 103/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.0979e-04
# Epoch 104/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.4095e-04
# Epoch 105/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.5295e-04
# Epoch 106/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.7414e-04
# Epoch 107/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.7693e-04
# Epoch 108/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.0970e-04
# Epoch 109/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.3016e-04
# Epoch 110/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.6693e-04
# Epoch 111/120
# 561/561 [==============================] - 4s 7ms/step - loss: 8.9827e-04
# Epoch 112/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.8793e-04
# Epoch 113/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.2635e-04
# Epoch 114/120
# 561/561 [==============================] - 4s 7ms/step - loss: 8.6842e-04
# Epoch 115/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.4443e-04
# Epoch 116/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.4698e-04
# Epoch 117/120
# 561/561 [==============================] - 4s 7ms/step - loss: 9.1897e-04
# Epoch 118/120
# 561/561 [==============================] - 4s 7ms/step - loss: 8.3264e-04
# Epoch 119/120
# 561/561 [==============================] - 4s 7ms/step - loss: 8.5561e-04
# Epoch 120/120
# 561/561 [==============================] - 4s 7ms/step - loss: 8.6559e-04

# %%
scaled_full_data.shape
# Out:
# (573, 1)

# %%
scaled_full_data[-length:].shape
# Out:
# (12, 1)

# %%
forecast = []

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(length):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)
    
    # store prediction
    forecast.append(current_pred[0]) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:, 1:, :], [current_pred], axis = 1)
# Out:
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
forecast = scaler.inverse_transform(forecast)

# %%
forecast
# Out:
# array([[ 92.87525546],
#        [ 84.6624425 ],
#        [ 78.97360455],
#        [ 89.87262316],
#        [100.91189971],
#        [110.48729953],
#        [113.66048392],
#        [115.5035948 ],
#        [127.43350358],
#        [120.54424588],
#        [114.59008215],
#        [101.64863097]])

# %%
df
# Out:
#             Production
# DATE
# 1972-01-01      59.962
# 1972-02-01      67.061
# 1972-03-01      74.235
# 1972-04-01      78.112
# 1972-05-01      84.764
# ...                ...
# 2019-05-01     114.561
# 2019-06-01     124.960
# 2019-07-01     110.263
# 2019-08-01     102.609
# 2019-09-01     101.587
#
# [573 rows x 1 columns]

# %%
forecast_index = pd.date_range(start = '2019-10-01', periods = length, freq = 'MS')

# %%
forecast_index
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01',
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(data = forecast, index = forecast_index, columns = ['Forecast'])

# %%
forecast_df
# Out:
#             Forecast
# 2019-10-01    92.875
# 2019-11-01    84.662
# 2019-12-01    78.974
# 2020-01-01    89.873
# 2020-02-01   100.912
# 2020-03-01   110.487
# 2020-04-01   113.660
# 2020-05-01   115.504
# 2020-06-01   127.434
# 2020-07-01   120.544
# 2020-08-01   114.590
# 2020-09-01   101.649

# %%
plt.figure(figsize = (16, 8))
plt.plot(df.index, df['Production'])
plt.plot(forecast_df.index, forecast_df['Forecast'])

# %%
ax = df.plot()
forecast_df.plot(ax = ax, figsize = (16, 8));

# %%
ax = df.plot()
forecast_df.plot(ax = ax, figsize = (16, 8))
plt.xlim('2019-06-01', '2020-12-01')
# Out:
# (593.0, 611.0)

# %%
dataset_total = pd.concat((df['Production'], forecast_df['Forecast']), axis=0)

# %%
dataset_total.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
